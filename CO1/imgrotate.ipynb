# %%
import numpy as np
from scipy import ndimage
import matplotlib.pyplot as plt
from PIL import Image
a=Image.open('dog.jpg') 
plt.imshow(a)
b=np.array(a)
c=ndimage.rotate(b,90)
plt.imshow(c)

# %%
z=ndimage.zoom(b,(0.15,0.15,1))
plt.imshow(z)
